# %% [markdown]
# # MIGMOBS
#
# ## Dataset construction V2.1
#
# **Natalia Dedandi**
#
#
# 'ARG', 'CHL', 'BOL', 'VEN'

# %% [markdown]
# **I1.1	Mouvements to country**
#
#
# https://migrationpolicycentre.eu/global-mobilities/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# prompt: open a csv file forma drive folder

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Replace 'your_file_path' with the actual path to your CSV file in Google Drive
file_path = '/content/drive/MyDrive/3. Proyectos/MIGMOBS_nat/3_data_repository/GT_Mobility_v1.0.csv'

df = pd.read_csv(file_path)
print(df.head())
# Out:
# Mounted at /content/drive
#    source_name  target_name source_iso3 target_iso3  year  estimated_trips  \
# 0  Afghanistan       Rwanda         AFG         RWA  2014             29.0
# 1  Afghanistan  Netherlands         AFG         NLD  2014           6991.0
# 2  Afghanistan        Congo         AFG         COG  2011              0.0
# 3  Afghanistan      Hungary         AFG         HUN  2012            308.0
# 4  Afghanistan   Cabo Verde         AFG         CPV  2012              0.0
#
#        dist source_region target_region source_subregion    target_subregion
# 0  5755.222          Asia        Africa    Southern Asia  Sub-Saharan Africa
# 1  5361.400          Asia        Europe    Southern Asia      Western Europe
# 2  7100.583          Asia        Africa    Southern Asia  Sub-Saharan Africa
# 3  4367.694          Asia        Europe    Southern Asia      Eastern Europe
# 4  9324.580          Asia        Africa    Southern Asia  Sub-Saharan Africa

# %% [markdown]
# **Number of movements from any country to Country of Analysis (ARG, CHIL)**

# %%
# Filter of countries of interest
countries = ['ARG', 'CHL', 'BOL', 'VEN']
#countries = ['ARG', 'CHL']
latam_df = df[(df['target_iso3'].isin(countries))]
print(latam_df.head())
# Out:
#      source_name                         target_name source_iso3 target_iso3  \
# 54   Afghanistan    Bolivia (Plurinational State of)         AFG         BOL
# 82   Afghanistan  Venezuela (Bolivarian Republic of)         AFG         VEN
# 158  Afghanistan    Bolivia (Plurinational State of)         AFG         BOL
# 220  Afghanistan                           Argentina         AFG         ARG
# 232  Afghanistan                               Chile         AFG         CHL
#
#      year  estimated_trips      dist source_region target_region  \
# 54   2011              3.0  15349.95          Asia      Americas
# 82   2013              0.0  13208.57          Asia      Americas
# 158  2014              3.0  15349.95          Asia      Americas
# 220  2012             19.0  15298.50          Asia      Americas
# 232  2014             14.0  16353.90          Asia      Americas
#
#     source_subregion                 target_subregion
# 54     Southern Asia  Latin America and the Caribbean
# 82     Southern Asia  Latin America and the Caribbean
# 158    Southern Asia  Latin America and the Caribbean
# 220    Southern Asia  Latin America and the Caribbean
# 232    Southern Asia  Latin America and the Caribbean

# %%
#contruyo un indicador por pais de destino y otro de origen sumando los estimated_by_hundred
latam_df_target = latam_df.groupby(['year','target_iso3',])['estimated_trips'].sum().reset_index()
latam_df_target
# Out:
#     year target_iso3  estimated_trips
# 0   2011         ARG       12133921.0
# 1   2011         BOL        1493371.0
# 2   2011         CHL        5916559.0
# 3   2011         VEN        2849358.0
# 4   2012         ARG       12678938.0
# 5   2012         BOL        1697027.0
# 6   2012         CHL        6528705.0
# 7   2012         VEN        3469671.0
# 8   2013         ARG       12500972.0
# 9   2013         BOL        1797211.0
# 10  2013         CHL        6644472.0
# 11  2013         VEN        3823580.0
# 12  2014         ARG       13044692.0
# 13  2014         BOL        1991253.0
# 14  2014         CHL        7172922.0
# 15  2014         VEN        3408417.0
# 16  2015         ARG       15021604.0
# 17  2015         BOL        2095841.0
# 18  2015         CHL        8405899.0
# 19  2015         VEN        3152904.0
# 20  2016         ARG       16989971.0
# 21  2016         BOL        2268038.0
# 22  2016         CHL        9791534.0
# 23  2016         VEN        3108475.0

# %%
db_indicators = latam_df_target[['target_iso3', 'year','estimated_trips']]
db_indicators = db_indicators.rename(columns={
    'target_iso3': 'country_code',
    'year': 'year',
    'estimated_trips': 'value'
})
print(db_indicators.head())
# Out:
#   country_code  year       value
# 0          ARG  2011  12133921.0
# 1          BOL  2011   1493371.0
# 2          CHL  2011   5916559.0
# 3          VEN  2011   2849358.0
# 4          ARG  2012  12678938.0

# %%
db_indicators['indicator'] = 'target_mobility'
db_indicators['fuente'] = 'GT_Mobility_v1.0'

# %%
db_indicators.head()
# Out:
#   country_code  year       value        indicator            fuente
# 0          ARG  2011  12133921.0  target_mobility  GT_Mobility_v1.0
# 1          BOL  2011   1493371.0  target_mobility  GT_Mobility_v1.0
# 2          CHL  2011   5916559.0  target_mobility  GT_Mobility_v1.0
# 3          VEN  2011   2849358.0  target_mobility  GT_Mobility_v1.0
# 4          ARG  2012  12678938.0  target_mobility  GT_Mobility_v1.0

# %%
# Pivot the table to have 'source_mobility' and 'target_mobility' as columns
pivot_df = db_indicators.pivot_table(index=['indicator', 'year'], columns='country_code', values='value').reset_index()
pivot_df
# Out:
# country_code        indicator  year         ARG        BOL        CHL  \
# 0             target_mobility  2011  12133921.0  1493371.0  5916559.0
# 1             target_mobility  2012  12678938.0  1697027.0  6528705.0
# 2             target_mobility  2013  12500972.0  1797211.0  6644472.0
# 3             target_mobility  2014  13044692.0  1991253.0  7172922.0
# 4             target_mobility  2015  15021604.0  2095841.0  8405899.0
# 5             target_mobility  2016  16989971.0  2268038.0  9791534.0
#
# country_code        VEN
# 0             2849358.0
# 1             3469671.0
# 2             3823580.0
# 3             3408417.0
# 4             3152904.0
# 5             3108475.0

# %%
df_plot=db_indicators[(db_indicators['indicator']=='target_mobility')]
title_plot="I1.1 target mobility  -  GT_Mobility_v1.0"

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='country_code', data=df_plot)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %% [markdown]
# **I1.2	Mouvements from 'CHL', 'BOL', 'VEN' to ARG**

# %%
latam_df = df[(df['source_iso3'].isin(countries)) & (df['target_iso3'] == "ARG")]

# %%
db_temp = latam_df[['source_iso3', 'year','estimated_trips']]
db_temp = db_temp.rename(columns={
    'source_iso3': 'country_code',
    'year': 'year',
    'estimated_trips': 'value'
})
print(db_temp.head())
# Out:
#       country_code  year     value
# 24578          BOL  2014  576578.0
# 24669          BOL  2012  406932.0
# 24694          BOL  2016  668119.0
# 24705          BOL  2013  465051.0
# 24821          BOL  2015  613185.0

# %%
db_temp['indicator'] = 'source_mobility_ARG'
db_temp['fuente'] = 'GT_Mobility_v1.0'

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
df_plot=db_indicators[(db_indicators['indicator']=='source_mobility_ARG')]
title_plot="I1.2.2 source mobility ARG- GT_Mobility_v1.0"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='country_code', data=df_plot)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %% [markdown]
# **I1.3	Mouvements to CHL**
#
# *Number of movements from 'ARG', 'BOL', 'VEN' to CHL*

# %%
latam_df = df[(df['source_iso3'].isin(countries)) & (df['target_iso3']=='CHL')]

# %%
db_temp = latam_df[['source_iso3', 'year','estimated_trips']]
db_temp = db_temp.rename(columns={
    'source_iso3': 'country_code',
    'year': 'year',
    'estimated_trips': 'value'
})
db_temp['indicator'] = 'source_mobility_CHL'
db_temp['fuente'] = 'GT_Mobility_v1.0'

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
df_plot=db_indicators[(db_indicators['indicator']=='source_mobility_CHL')]
title_plot="I1.2.3 source mobility CHL   -   GT_Mobility_v1.0"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='country_code', data=df_plot)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %% [markdown]
# **(2) Annual migration flow estimates: inmigration and emigration**
#
# from:
# https://riks.cris.unu.edu/annual-bilateral-migration-data
#
#
# 2.1 inmigration_stock

# %%
# Replace 'your_file_path' with the actual path to your CSV file in Google Drive
file_path = '/content/drive/MyDrive/3. Proyectos/MIGMOBS_nat/3_data_repository/migration_imputed_RIKS_dec2021.csv'

df2 = pd.read_csv(file_path)
print(df2.head())
# Out:
#   iso_or               origin iso_des destination  year  stock  flow  inflow  \
# 0    AAB  Antigua and Barbuda     ABW       Aruba  1960     16   NaN     NaN
# 1    AAB  Antigua and Barbuda     ABW       Aruba  1961     16   0.0     NaN
# 2    AAB  Antigua and Barbuda     ABW       Aruba  1962     15  -1.0     NaN
# 3    AAB  Antigua and Barbuda     ABW       Aruba  1963     15   0.0     NaN
# 4    AAB  Antigua and Barbuda     ABW       Aruba  1964     15   0.0     NaN
#
#    outflow
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
latam_mig_df = df2[(df2['iso_des'].isin(countries))]
print(latam_mig_df.head())
# Out:
#     iso_or               origin iso_des destination  year  stock  flow  \
# 436    AAB  Antigua and Barbuda     ARG   Argentina  1960      0   0.0
# 437    AAB  Antigua and Barbuda     ARG   Argentina  1961      0   0.0
# 438    AAB  Antigua and Barbuda     ARG   Argentina  1962      0   0.0
# 439    AAB  Antigua and Barbuda     ARG   Argentina  1963      0   0.0
# 440    AAB  Antigua and Barbuda     ARG   Argentina  1964      0   0.0
#
#      inflow  outflow
# 436     NaN      NaN
# 437     NaN      NaN
# 438     NaN      NaN
# 439     NaN      NaN
# 440     NaN      NaN

# %%
inmigration_df = latam_mig_df.groupby(['year', 'iso_des'])['stock'].sum().reset_index()
inmigration_df
# Out:
#      year iso_des    stock
# 0    1960     ARG  2683416
# 1    1960     BOL    43730
# 2    1960     CHL   109563
# 3    1960     VEN   510822
# 4    1961     ARG  2630230
# ..    ...     ...      ...
# 239  2019     VEN  1343206
# 240  2020     ARG  2245714
# 241  2020     BOL   160289
# 242  2020     CHL  1601702
# 243  2020     VEN  1325156
#
# [244 rows x 3 columns]

# %%
#Creo el indicador

db_temp = inmigration_df[['iso_des', 'year','stock']]
db_temp = db_temp.rename(columns={
    'iso_des': 'country_code',
    'year': 'year',
    'stock': 'value'
})
print(db_temp.head())
# Out:
#   country_code  year    value
# 0          ARG  1960  2683416
# 1          BOL  1960    43730
# 2          CHL  1960   109563
# 3          VEN  1960   510822
# 4          ARG  1961  2630230

# %%
db_temp['indicator'] = 'inmigration_stock'
db_temp['fuente'] = 'UNU-CRIS'

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
df_plot=db_indicators[(db_indicators['indicator']=='inmigration_stock')]
title_plot="I2.1 inmigration_stock   -   UNU-CRIS"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='country_code', data=df_plot)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %%
years_to_filter = [1960, 1970, 1980, 1991, 2001, 2010]
filtered_df = db_indicators[(db_indicators['indicator'] == 'inmigration_stock') & (db_indicators['year'].isin(years_to_filter))& (db_indicators['country_code']=='ARG')]

# Print the filtered DataFrame
filtered_df
# Out:
#     country_code  year      value          indicator    fuente
# 0            ARG  1960  2683416.0  inmigration_stock  UNU-CRIS
# 40           ARG  1970  1995770.0  inmigration_stock  UNU-CRIS
# 80           ARG  1980   976756.0  inmigration_stock  UNU-CRIS
# 124          ARG  1991  1603133.0  inmigration_stock  UNU-CRIS
# 164          ARG  2001  1493360.0  inmigration_stock  UNU-CRIS
# 200          ARG  2010  1785826.0  inmigration_stock  UNU-CRIS

# %% [markdown]
# the values are not exactly the same as the official census data

# %% [markdown]
# Data correction from offical data from CENSUS ARGENTINA
#
# https://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S1405-74252016000300201

# %%
# Replace 'your_file_path' with the actual path to your CSV file in Google Drive
file_path = '/content/drive/MyDrive/3. Proyectos/MIGMOBS_nat/3_data_repository/data_correction_v1.csv'

df_correction = pd.read_csv(file_path)
print(df_correction.head())
# Out:
#   country_code  year    value                indicator          fuente
# 0          ARG  1960  2604447  inmigration_stock_INDEC  INDEC - Census
# 1          ARG  1970  2210400  inmigration_stock_INDEC  INDEC - Census
# 2          ARG  1980  1912217  inmigration_stock_INDEC  INDEC - Census
# 3          ARG  1991  1628210  inmigration_stock_INDEC  INDEC - Census
# 4          ARG  2001  1531940  inmigration_stock_INDEC  INDEC - Census

# %%
# this is for update the data, I'll add a new indicator for comparison

# Assuming df_correction has columns 'indicator', 'year', 'country_code', and the value to update
#for index, row in df_correction.iterrows():
#  db_indicators.loc[(db_indicators['indicator'] == row['indicator']) &
#                    (db_indicators['year'] == row['year']) &
#                    (db_indicators['country_code'] == row['country_code']),'value'] = row['value'] # Replace 'value' with the actual column name in df_correction that holds the updated values

db_indicators = pd.concat([db_indicators, df_correction], axis=0)

# %%
years_to_filter = [1960, 1970, 1980, 1991, 2001, 2010]
filtered_df = db_indicators[(db_indicators['indicator'] == 'inmigration_stock_INDEC') & (db_indicators['year'].isin(years_to_filter))& (db_indicators['country_code']=='ARG')]

# Print the filtered DataFrame
filtered_df
# Out:
#   country_code  year      value                indicator          fuente
# 0          ARG  1960  2604447.0  inmigration_stock_INDEC  INDEC - Census
# 1          ARG  1970  2210400.0  inmigration_stock_INDEC  INDEC - Census
# 2          ARG  1980  1912217.0  inmigration_stock_INDEC  INDEC - Census
# 3          ARG  1991  1628210.0  inmigration_stock_INDEC  INDEC - Census
# 4          ARG  2001  1531940.0  inmigration_stock_INDEC  INDEC - Census
# 5          ARG  2010  1805957.0  inmigration_stock_INDEC  INDEC - Census

# %% [markdown]
# The CENSUS and CRIS data are very different between 1970 and 1990, i.e. during the dictatorship.

# %% [markdown]
# **I2.2	Inmigration stock	**
#
#
# inmigration_stock_ONU

# %%
pip install wbgapi
# Out:
# Collecting wbgapi
#   Downloading wbgapi-1.0.12-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from wbgapi) (2.32.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from wbgapi) (6.0.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from wbgapi) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->wbgapi) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->wbgapi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->wbgapi) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->wbgapi) (2024.12.14)
# Downloading wbgapi-1.0.12-py3-none-any.whl (36 kB)
# Installing collected packages: wbgapi
# Successfully installed wbgapi-1.0.12

# %%
import wbgapi as wb

# %%
mig_stock=wb.data.DataFrame('SM.POP.TOTL', ['ARG', 'CHL','BOL','VEN'], range(1960, 2022), labels=True)
mig_stock = mig_stock.reset_index()
mig_stock
# Out:
#   economy        Country     YR1960  YR1961  YR1962  YR1963  YR1964  \
# 0     VEN  Venezuela, RB   509504.0     NaN     NaN     NaN     NaN
# 1     BOL        Bolivia    42709.0     NaN     NaN     NaN     NaN
# 2     CHL          Chile   104805.0     NaN     NaN     NaN     NaN
# 3     ARG      Argentina  2601188.0     NaN     NaN     NaN     NaN
#
#       YR1965  YR1966  YR1967  ...  YR2012  YR2013  YR2014     YR2015  YR2016  \
# 0   563247.0     NaN     NaN  ...     NaN     NaN     NaN  1404448.0     NaN
# 1    46944.0     NaN     NaN  ...     NaN     NaN     NaN   142989.0     NaN
# 2    97551.0     NaN     NaN  ...     NaN     NaN     NaN   469436.0     NaN
# 3  2409183.0     NaN     NaN  ...     NaN     NaN     NaN  2086302.0     NaN
#
#    YR2017  YR2018  YR2019  YR2020  YR2021
# 0     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN
#
# [4 rows x 64 columns]

# %%
mig_latam = mig_stock.melt(id_vars=['economy', 'Country'],
                    value_vars=[col for col in mig_stock.columns if col.startswith('YR')],
                    var_name='year',
                    value_name='mig_stock')

# Limpiar la columna 'YEAR' eliminando el prefijo 'YR'
mig_latam['year'] = mig_latam['year'].str.replace('YR', '')

# Mostrar las primeras filas de la tabla transformada
print(mig_latam.head())
# Out:
#   economy        Country  year  mig_stock
# 0     VEN  Venezuela, RB  1960   509504.0
# 1     BOL        Bolivia  1960    42709.0
# 2     CHL          Chile  1960   104805.0
# 3     ARG      Argentina  1960  2601188.0
# 4     VEN  Venezuela, RB  1961        NaN

# %%
mig_latam = mig_latam.dropna(subset=['mig_stock'])

# %%
#creo el indicador y lo agrego a la base
db_temp = mig_latam[['economy', 'year','mig_stock']]
db_temp = db_temp.rename(columns={
    'economy': 'country_code',
    'year': 'year',
    'mig_stock': 'value'
})
db_temp['indicator'] = 'inmigration_stock_wb'
db_temp['fuente'] = 'World Bank API'
print(db_temp.head())
# Out:
#    country_code  year      value             indicator          fuente
# 0           VEN  1960   509504.0  inmigration_stock_wb  World Bank API
# 1           BOL  1960    42709.0  inmigration_stock_wb  World Bank API
# 2           CHL  1960   104805.0  inmigration_stock_wb  World Bank API
# 3           ARG  1960  2601188.0  inmigration_stock_wb  World Bank API
# 20          VEN  1965   563247.0  inmigration_stock_wb  World Bank API

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
db_indicators = db_indicators.dropna(subset=['value'])

# %%
db_indicators['year'] = db_indicators['year'].astype(int)

# %%
# Filter the db_indicators DataFrame
# Convert 'year' column to integer

filtered_df = db_indicators[
    ((db_indicators['indicator'] == 'inmigration_stock_wb') |  (db_indicators['indicator'] == 'inmigration_stock') |  (db_indicators['indicator'] == 'inmigration_stock_INDEC'))&
    (db_indicators['country_code'] == 'ARG') &
    (db_indicators['year'] >= 1970) & (db_indicators['year'] <= 1995)
]

# %%
plt.figure(figsize=(15, 10))
ax = sns.barplot(x='year', y='value', hue='indicator', data=filtered_df, palette = "Set2")
plt.title('Migrant stock indicator comparation:INDEC (official), UNU-CRIS and World Bank/Population division ONU')
plt.xlabel('Year')
plt.ylabel('Migration stock')

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# Check the data from OIM
#
# OIM API Acces
#
# https://www.migrationdataportal.org/
#
# API documentation: https://www.migrationdataportal.org/handbooks/global-migration-data-portal-api-documentation

# %%
# importing necessary libraries.

import requests

# Setting up the API URL.

base_url = 'https://www.migrationdataportal.org/api/international-values?'

# Setting up the request header with API key.

header_ = {'api-key': 'ab0b531fc309ca5080851f5f9101145d'}

# %%
# Defining the parameters for the GET request.

params_ = {
     # Specifying the indicators.
    'indicator': 'stock_abs_',
    # Specifying the years for which data is requested.
    'year': '1960+2020'}

# %%
params = {
    'page': 0,
    'indicator': 'stock_abs_+default'}

# List to store data from all pages
all_data = []

while True:
    # Make API request for the current page
    response = requests.get(base_url, headers=header_, params=params)
    response_json = response.json()

    print(response_json["pagination"]["current_page"])
    print(response_json["pagination"]["total_pages"])

    # Append data from the current page
    observations = response_json.get("observations", [])
    all_data.extend(observations)

   # Check if there are more pages
    if params["page"] >= response_json["pagination"]["total_pages"]-1:
        break

    # Move to the next page
    params["page"] += 1

# Convert the aggregated data into a DataFrame
df_oim_complete = pd.DataFrame(all_data)
# Out:
# 0
# 2
# 1
# 2

# %%
latam_df_oim = df_oim_complete[df_oim_complete['REF_AREA'].isin(["32", "68", "152", "862"])]
latam_df_oim
# Out:
#           id IOM_REGION REF_AREA                       REF_AREA_DESC  \
# 542  1431361                  32                           Argentina
# 543  1431366                  32                           Argentina
# 544  1431371                  32                           Argentina
# 545  1431376                  32                           Argentina
# 546  1431381                  32                           Argentina
# 547  1431386                  32                           Argentina
# 548  1431391                  32                           Argentina
# 549  1431396                  68    Bolivia (Plurinational State of)
# 550  1431401                  68    Bolivia (Plurinational State of)
# 551  1431406                  68    Bolivia (Plurinational State of)
# 552  1431411                  68    Bolivia (Plurinational State of)
# 553  1431416                  68    Bolivia (Plurinational State of)
# 554  1431421                  68    Bolivia (Plurinational State of)
# 555  1431426                  68    Bolivia (Plurinational State of)
# 563  1431466                 152                               Chile
# 564  1431471                 152                               Chile
# 565  1431476                 152                               Chile
# 566  1431481                 152                               Chile
# 567  1431486                 152                               Chile
# 568  1431491                 152                               Chile
# 569  1431496                 152                               Chile
# 619  1431746                 862  Venezuela (Bolivarian Republic of)
# 620  1431751                 862  Venezuela (Bolivarian Republic of)
# 621  1431756                 862  Venezuela (Bolivarian Republic of)
# 622  1431761                 862  Venezuela (Bolivarian Republic of)
# 623  1431766                 862  Venezuela (Bolivarian Republic of)
# 624  1431771                 862  Venezuela (Bolivarian Republic of)
# 625  1431776                 862  Venezuela (Bolivarian Republic of)
#
#     REF_AREA_TYPE   INDICATOR                       INDICATOR_DESC  \
# 542       Country  stock_abs_  International migrant stock (Total)
# 543       Country  stock_abs_  International migrant stock (Total)
# 544       Country  stock_abs_  International migrant stock (Total)
# 545       Country  stock_abs_  International migrant stock (Total)
# 546       Country  stock_abs_  International migrant stock (Total)
# 547       Country  stock_abs_  International migrant stock (Total)
# 548       Country  stock_abs_  International migrant stock (Total)
# 549       Country  stock_abs_  International migrant stock (Total)
# 550       Country  stock_abs_  International migrant stock (Total)
# 551       Country  stock_abs_  International migrant stock (Total)
# 552       Country  stock_abs_  International migrant stock (Total)
# 553       Country  stock_abs_  International migrant stock (Total)
# 554       Country  stock_abs_  International migrant stock (Total)
# 555       Country  stock_abs_  International migrant stock (Total)
# 563       Country  stock_abs_  International migrant stock (Total)
# 564       Country  stock_abs_  International migrant stock (Total)
# 565       Country  stock_abs_  International migrant stock (Total)
# 566       Country  stock_abs_  International migrant stock (Total)
# 567       Country  stock_abs_  International migrant stock (Total)
# 568       Country  stock_abs_  International migrant stock (Total)
# 569       Country  stock_abs_  International migrant stock (Total)
# 619       Country  stock_abs_  International migrant stock (Total)
# 620       Country  stock_abs_  International migrant stock (Total)
# 621       Country  stock_abs_  International migrant stock (Total)
# 622       Country  stock_abs_  International migrant stock (Total)
# 623       Country  stock_abs_  International migrant stock (Total)
# 624       Country  stock_abs_  International migrant stock (Total)
# 625       Country  stock_abs_  International migrant stock (Total)
#
#     UNIT_MEASURE TIME_PERIOD   OBS_VALUE  \
# 542       Totals        1990  1649919.00
# 543       Totals        1995  1595069.00
# 544       Totals        2000  1540219.00
# 545       Totals        2005  1674163.00
# 546       Totals        2010  1805957.00
# 547       Totals        2015  2086301.00
# 548       Totals        2020  2281728.00
# 549       Totals        1990    73758.00
# 550       Totals        1995    83598.00
# 551       Totals        2000    92658.00
# 552       Totals        2005   107745.00
# 553       Totals        2010   122846.00
# 554       Totals        2015   143008.00
# 555       Totals        2020   164121.00
# 563       Totals        1990   107501.00
# 564       Totals        1995   142417.00
# 565       Totals        2000   177332.00
# 566       Totals        2005   276360.00
# 567       Totals        2010   375388.00
# 568       Totals        2015   639724.00
# 569       Totals        2020  1645015.00
# 619       Totals        1990  1025009.00
# 620       Totals        1995  1019996.00
# 621       Totals        2000  1013738.00
# 622       Totals        2005  1076474.00
# 623       Totals        2010  1347347.00
# 624       Totals        2015  1404448.00
# 625       Totals        2020  1324193.00
#
#                                           IND_FOOTNOTE     DATA_SOURCE  \
# 542  This indicator visualizes estimates on interna...  UN DESA, 2020
# 543  This indicator visualizes estimates on interna...  UN DESA, 2020
# 544  This indicator visualizes estimates on interna...  UN DESA, 2020
# 545  This indicator visualizes estimates on interna...  UN DESA, 2020
# 546  This indicator visualizes estimates on interna...  UN DESA, 2020
# 547  This indicator visualizes estimates on interna...  UN DESA, 2020
# 548  This indicator visualizes estimates on interna...  UN DESA, 2020
# 549  This indicator visualizes estimates on interna...  UN DESA, 2020
# 550  This indicator visualizes estimates on interna...  UN DESA, 2020
# 551  This indicator visualizes estimates on interna...  UN DESA, 2020
# 552  This indicator visualizes estimates on interna...  UN DESA, 2020
# 553  This indicator visualizes estimates on interna...  UN DESA, 2020
# 554  This indicator visualizes estimates on interna...  UN DESA, 2020
# 555  This indicator visualizes estimates on interna...  UN DESA, 2020
# 563  This indicator visualizes estimates on interna...  UN DESA, 2020
# 564  This indicator visualizes estimates on interna...  UN DESA, 2020
# 565  This indicator visualizes estimates on interna...  UN DESA, 2020
# 566  This indicator visualizes estimates on interna...  UN DESA, 2020
# 567  This indicator visualizes estimates on interna...  UN DESA, 2020
# 568  This indicator visualizes estimates on interna...  UN DESA, 2020
# 569  This indicator visualizes estimates on interna...  UN DESA, 2020
# 619  This indicator visualizes estimates on interna...  UN DESA, 2020
# 620  This indicator visualizes estimates on interna...  UN DESA, 2020
# 621  This indicator visualizes estimates on interna...  UN DESA, 2020
# 622  This indicator visualizes estimates on interna...  UN DESA, 2020
# 623  This indicator visualizes estimates on interna...  UN DESA, 2020
# 624  This indicator visualizes estimates on interna...  UN DESA, 2020
# 625  This indicator visualizes estimates on interna...  UN DESA, 2020
#
#                                       DATA_SOURCE_LINK
# 542  https://www.un.org/development/desa/pd/content...
# 543  https://www.un.org/development/desa/pd/content...
# 544  https://www.un.org/development/desa/pd/content...
# 545  https://www.un.org/development/desa/pd/content...
# 546  https://www.un.org/development/desa/pd/content...
# 547  https://www.un.org/development/desa/pd/content...
# 548  https://www.un.org/development/desa/pd/content...
# 549  https://www.un.org/development/desa/pd/content...
# 550  https://www.un.org/development/desa/pd/content...
# 551  https://www.un.org/development/desa/pd/content...
# 552  https://www.un.org/development/desa/pd/content...
# 553  https://www.un.org/development/desa/pd/content...
# 554  https://www.un.org/development/desa/pd/content...
# 555  https://www.un.org/development/desa/pd/content...
# 563  https://www.un.org/development/desa/pd/content...
# 564  https://www.un.org/development/desa/pd/content...
# 565  https://www.un.org/development/desa/pd/content...
# 566  https://www.un.org/development/desa/pd/content...
# 567  https://www.un.org/development/desa/pd/content...
# 568  https://www.un.org/development/desa/pd/content...
# 569  https://www.un.org/development/desa/pd/content...
# 619  https://www.un.org/development/desa/pd/content...
# 620  https://www.un.org/development/desa/pd/content...
# 621  https://www.un.org/development/desa/pd/content...
# 622  https://www.un.org/development/desa/pd/content...
# 623  https://www.un.org/development/desa/pd/content...
# 624  https://www.un.org/development/desa/pd/content...
# 625  https://www.un.org/development/desa/pd/content...

# %%
db_temp = latam_df_oim[['REF_AREA_DESC', 'TIME_PERIOD','OBS_VALUE']]

# %%
db_temp = db_temp.replace({'REF_AREA_DESC': {'Argentina': 'ARG',
                                            'Bolivia (Plurinational State of)': 'BOL',
                                            'Chile': 'CHL',
                                            'Venezuela (Bolivarian Republic of)': 'VEN'}})

# %%
#creo el indicador y lo agrego a la base
db_temp = db_temp.rename(columns={
    'REF_AREA_DESC': 'country_code',
    'TIME_PERIOD': 'year',
    'OBS_VALUE': 'value'
})
db_temp['indicator'] = 'inmigration_stock_oim'
db_temp['fuente'] = 'OIM/UN DESA, 2020'
print(db_temp.head())
# Out:
#     country_code  year       value              indicator             fuente
# 542          ARG  1990  1649919.00  inmigration_stock_oim  OIM/UN DESA, 2020
# 543          ARG  1995  1595069.00  inmigration_stock_oim  OIM/UN DESA, 2020
# 544          ARG  2000  1540219.00  inmigration_stock_oim  OIM/UN DESA, 2020
# 545          ARG  2005  1674163.00  inmigration_stock_oim  OIM/UN DESA, 2020
# 546          ARG  2010  1805957.00  inmigration_stock_oim  OIM/UN DESA, 2020

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
db_indicators = db_indicators.dropna(subset=['value'])

# %%
db_indicators['year'] = db_indicators['year'].astype(int)


filtered_df = db_indicators[
    ((db_indicators['indicator'] == 'inmigration_stock_wb') |  (db_indicators['indicator'] == 'inmigration_stock') |  (db_indicators['indicator'] == 'inmigration_stock_INDEC') | (db_indicators['indicator'] == 'inmigration_stock_oim'))&
    (db_indicators['country_code'] == 'ARG') &
    (db_indicators['year'] >= 1970) & (db_indicators['year'] <= 1995)
]
filtered_df['value'] = filtered_df['value'].astype(float)
filtered_df['value'] = filtered_df['value'].astype(int)
filtered_df
# Out:
# <ipython-input-51-f51aae3b39a4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['value'] = filtered_df['value'].astype(float)
# <ipython-input-51-f51aae3b39a4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['value'] = filtered_df['value'].astype(int)
#     country_code  year    value                indicator             fuente
# 40           ARG  1970  1995770        inmigration_stock           UNU-CRIS
# 44           ARG  1971  1823610        inmigration_stock           UNU-CRIS
# 48           ARG  1972  1575300        inmigration_stock           UNU-CRIS
# 52           ARG  1973  1405898        inmigration_stock           UNU-CRIS
# 56           ARG  1974  1161941        inmigration_stock           UNU-CRIS
# 60           ARG  1975   980166        inmigration_stock           UNU-CRIS
# 64           ARG  1976   877676        inmigration_stock           UNU-CRIS
# 68           ARG  1977   889792        inmigration_stock           UNU-CRIS
# 72           ARG  1978   906372        inmigration_stock           UNU-CRIS
# 76           ARG  1979   931427        inmigration_stock           UNU-CRIS
# 80           ARG  1980   976756        inmigration_stock           UNU-CRIS
# 84           ARG  1981  1014735        inmigration_stock           UNU-CRIS
# 88           ARG  1982  1045893        inmigration_stock           UNU-CRIS
# 92           ARG  1983  1071701        inmigration_stock           UNU-CRIS
# 96           ARG  1984  1114034        inmigration_stock           UNU-CRIS
# 100          ARG  1985  1185273        inmigration_stock           UNU-CRIS
# 104          ARG  1986  1247687        inmigration_stock           UNU-CRIS
# 108          ARG  1987  1343188        inmigration_stock           UNU-CRIS
# 112          ARG  1988  1449510        inmigration_stock           UNU-CRIS
# 116          ARG  1989  1545621        inmigration_stock           UNU-CRIS
# 120          ARG  1990  1607941        inmigration_stock           UNU-CRIS
# 124          ARG  1991  1603133        inmigration_stock           UNU-CRIS
# 128          ARG  1992  1605884        inmigration_stock           UNU-CRIS
# 132          ARG  1993  1590425        inmigration_stock           UNU-CRIS
# 136          ARG  1994  1559271        inmigration_stock           UNU-CRIS
# 140          ARG  1995  1524944        inmigration_stock           UNU-CRIS
# 1            ARG  1970  2210400  inmigration_stock_INDEC     INDEC - Census
# 2            ARG  1980  1912217  inmigration_stock_INDEC     INDEC - Census
# 3            ARG  1991  1628210  inmigration_stock_INDEC     INDEC - Census
# 43           ARG  1970  2219411     inmigration_stock_wb     World Bank API
# 63           ARG  1975  2064199     inmigration_stock_wb     World Bank API
# 83           ARG  1980  1920798     inmigration_stock_wb     World Bank API
# 103          ARG  1985  1780443     inmigration_stock_wb     World Bank API
# 123          ARG  1990  1649919     inmigration_stock_wb     World Bank API
# 143          ARG  1995  1595069     inmigration_stock_wb     World Bank API
# 542          ARG  1990  1649919    inmigration_stock_oim  OIM/UN DESA, 2020
# 543          ARG  1995  1595069    inmigration_stock_oim  OIM/UN DESA, 2020

# %%
plt.figure(figsize=(15, 10))
ax = sns.barplot(x='year', y='value', hue='indicator', data=filtered_df, palette = "Set2")
plt.title('Migrant stock indicator source comparation')
plt.xlabel('Year')
plt.ylabel('Migration stock')

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# WorldBanck data are similar to IOM / UN DESA data but the years do not match.

# %% [markdown]
# ## Emigration data
#
# **I2.2 Emigration Stocks**

# %%
latam_mig_df = df2[(df2['iso_or'].isin(countries))]
print(latam_mig_df.head())
# Out:
#        iso_or     origin iso_des          destination  year  stock  flow  \
# 110310    ARG  Argentina     AAB  Antigua and Barbuda  1960      3   NaN
# 110311    ARG  Argentina     AAB  Antigua and Barbuda  1961      3   0.0
# 110312    ARG  Argentina     AAB  Antigua and Barbuda  1962      3   0.0
# 110313    ARG  Argentina     AAB  Antigua and Barbuda  1963      3   0.0
# 110314    ARG  Argentina     AAB  Antigua and Barbuda  1964      3   0.0
#
#         inflow  outflow
# 110310     NaN      NaN
# 110311     NaN      NaN
# 110312     NaN      NaN
# 110313     NaN      NaN
# 110314     NaN      NaN

# %%
emigration_df = latam_mig_df.groupby(['year', 'iso_or'])['stock'].sum().reset_index()
emigration_df
# Out:
#      year iso_or    stock
# 0    1960    ARG   154466
# 1    1960    BOL   123588
# 2    1960    CHL   171641
# 3    1960    VEN    53994
# 4    1961    ARG   160017
# ..    ...    ...      ...
# 239  2019    VEN  4307549
# 240  2020    ARG  1077397
# 241  2020    BOL   927708
# 242  2020    CHL   643801
# 243  2020    VEN  5414459
#
# [244 rows x 3 columns]

# %%
db_temp = emigration_df[['iso_or', 'year','stock']]
db_temp = db_temp.rename(columns={
    'iso_or': 'country_code',
    'year': 'year',
    'stock': 'value'
})
print(db_temp.head())
# Out:
#   country_code  year   value
# 0          ARG  1960  154466
# 1          BOL  1960  123588
# 2          CHL  1960  171641
# 3          VEN  1960   53994
# 4          ARG  1961  160017

# %%
db_temp['indicator'] = 'emigration_stock'
db_temp['fuente'] = 'UNU-CRIS'

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
filtered_df = db_indicators[db_indicators['indicator'] == 'emigration_stock']

countries_plot=['CHL', 'ARG']
country_df = filtered_df[filtered_df['country_code'].isin(countries_plot)]

# Create the time series plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="darkgrid")
sns.lineplot(x='year', y='value', hue='country_code', data=country_df)

plt.xlabel('Year')
plt.ylabel('Emigration stock')
plt.title('Estimated emigration stock Over Time for CHL and ARG (emigration_stock)')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %%
countries_plot=['BOL','VEN']
country_df = filtered_df[filtered_df['country_code'].isin(countries_plot)]

# Create the time series plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="darkgrid")
sns.lineplot(x='year', y='value', hue='country_code', data=country_df)

plt.xlabel('Year')
plt.ylabel('Emigration stock')
plt.title('Estimated emigration stock)')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %%
filtered_df[(filtered_df['country_code']=='ARG')]
# Out:
#     country_code  year    value         indicator    fuente
# 0            ARG  1960   154466  emigration_stock  UNU-CRIS
# 4            ARG  1961   160017  emigration_stock  UNU-CRIS
# 8            ARG  1962   155155  emigration_stock  UNU-CRIS
# 12           ARG  1963   156476  emigration_stock  UNU-CRIS
# 16           ARG  1964   159048  emigration_stock  UNU-CRIS
# ..           ...   ...      ...               ...       ...
# 224          ARG  2016   967760  emigration_stock  UNU-CRIS
# 228          ARG  2017   990303  emigration_stock  UNU-CRIS
# 232          ARG  2018  1021045  emigration_stock  UNU-CRIS
# 236          ARG  2019  1045452  emigration_stock  UNU-CRIS
# 240          ARG  2020  1077397  emigration_stock  UNU-CRIS
#
# [61 rows x 5 columns]

# %% [markdown]
# These data are also strange. No emigration peak is shown between 1970 and 1980 for Argentina during the dictatorship period, nor in 2001 (the economic crisis)
#
# However, the figures are not that far off from some estimates in research articles. A thorough review would be essential.
#
#
# En Argentina no hay datos de emigración fidedignos.
# https://chequeado.com/ultimas-noticias/macri-el-exodo-que-lamentablemente-ha-habido-en-la-argentina-en-el-ultimo-ano-y-medio-no-se-vio-nunca-en-nuestra-historia/
#
#
# Libro de emigración de Susana
# https://biblioteca.clacso.edu.ar/Argentina/iigg-uba/20110715050635/LibroSur-Norte.pdf
#
# Con posterioridad, los trabajos indagaron sobre las principales características del flujo originado después del golpe de
# Estado de 1976, e intentaron cuantificar el fenómeno, advirtiendo sobre la carencia de información confiable. En la década
# de 1960-1970 habrían emigrado 185.000 argentinos, y para la
# década siguiente la cifra estimada ascendería a los 200.000;
# Estados Unidos de Norteamérica y España resultaron los países
# principalmente elegidos (Gurrieri, 1982; Orsatti, 1982; Oteiza,
# 1969; Bertoncello, 1986; Bertoncello y Lattes, 1986)
#
#
# El diario La Nación del 20 de diciembre de
# 2002 afirma que son 587.005 los argentinos que viven en el
# extranjero, según datos suministrados por la Cancillería argentina. Una nota publicada en el diario Clarín en noviembre de
# 2002
#
# Un reciente artículo informa que serían 909.180 los argentinos que viven en el
# extranjero. Estados Unidos de Norteamérica, España, Israel y
# Brasil son los países con mayor cantidad de residentes (La Nación, 29-5-2005).

# %%
# Filter for indicators 'emigration_stock' and 'inmigration_stock'
plt.figure(figsize=(15, 10))

indicators = ['emigration_stock', 'inmigration_stock']
filtered_df = db_indicators[db_indicators['indicator'].isin(indicators)]

# Filter for country ARG
country_df = filtered_df[filtered_df['country_code'] == 'ARG']
country_df['year'] = country_df['year'].astype(int)

# Create the barplot using seaborn
sns.set_theme(style="darkgrid")
sns.barplot(x='year', y='value', hue='indicator', data=country_df)

plt.xlabel('Year')
plt.ylabel('Stock')
plt.title('Emigration and Immigration Stock for ARG (UNU-CRIS database)')
plt.legend(title='Indicator')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-61-1297c44f9216>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_df['year'] = country_df['year'].astype(int)

# %%
plt.figure(figsize=(15, 10))

# Filter for indicators 'emigration_stock' and 'inmigration_stock'
indicators = ['emigration_stock', 'inmigration_stock']
filtered_df = db_indicators[db_indicators['indicator'].isin(indicators)]

# Filter for country ARG
country_df = filtered_df[filtered_df['country_code'] == 'CHL']

# Create the barplot using seaborn
sns.set_theme(style="darkgrid")
sns.barplot(x='year', y='value', hue='indicator', data=country_df)

plt.xlabel('Year')
plt.ylabel('Stock')
plt.title('Emigration and Immigration Stock for CHL (UNU-CRIS database)')
plt.legend(title='Indicator')
plt.grid(True)
plt.show()

# %%
# prompt: calcular la diferencia entre inmigration_stock y emigration_stock (value) de db_indicator por year y country_code

# Calculate the difference between 'inmigration_stock' and 'emigration_stock'
difference_df = db_indicators[db_indicators['indicator'].isin(['inmigration_stock', 'emigration_stock'])]
difference_df = difference_df.pivot_table(index=['year', 'country_code'], columns='indicator', values='value').reset_index()
difference_df['difference'] = difference_df['inmigration_stock'] - difference_df['emigration_stock']
print(difference_df.head())

# Plotting the difference
plt.figure(figsize=(15, 10))
sns.lineplot(x='year', y='difference', hue='country_code', data=difference_df)
plt.title('Difference between Immigration and Emigration Stock')
plt.xlabel('Year')
plt.ylabel('Difference')
plt.show()
# Out:
# indicator  year country_code emigration_stock inmigration_stock difference
# 0          1960          ARG         154466.0         2683416.0  2528950.0
# 1          1960          BOL         123588.0           43730.0   -79858.0
# 2          1960          CHL         171641.0          109563.0   -62078.0
# 3          1960          VEN          53994.0          510822.0   456828.0
# 4          1961          ARG         160017.0         2630230.0  2470213.0

# %%
db_temp = difference_df[['country_code', 'year','difference']]
db_temp = db_temp.rename(columns={
    'country_code': 'country_code',
    'year': 'year',
    'difference': 'value'
})
print(db_temp.head())
# Out:
# indicator country_code  year      value
# 0                  ARG  1960  2528950.0
# 1                  BOL  1960   -79858.0
# 2                  CHL  1960   -62078.0
# 3                  VEN  1960   456828.0
# 4                  ARG  1961  2470213.0

# %%
db_temp['indicator'] = 'net_migration_calculated'
db_temp['fuente'] = 'calculated - UNU-CRIS'
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %% [markdown]
# I use the NET migration population division data (difference between immigration and emigration) and compare it with the CRIS-UN data.
# The API does not work well so I download the data from here:
#
# https://population.un.org/wpp/downloads?folder=Standard%20Projections&group=Most%20used
#
# Total net number of migrants
# Net number of migrants, that is, the number of immigrants minus the number of emigrants.

# %%
# Replace 'your_file_path' with the actual path to your CSV file in Google Drive
file_path = '/content/drive/MyDrive/3. Proyectos/MIGMOBS_nat/3_data_repository/onu_population_indicators.csv'

df_onu = pd.read_csv(file_path)
print(df_onu.head())
# Out:
#   country_code  year  population  net_number_migrants  rate_net_migration
# 0          ARG  1950    16849682                60480                 3.6
# 1          ARG  1951    17186391                54478                 3.1
# 2          ARG  1952    17526543                48149                 2.7
# 3          ARG  1953    17871212                41687                 2.3
# 4          ARG  1954    18211391                35623                 1.9

# %%
db_temp = df_onu[['country_code', 'year','net_number_migrants']]
db_temp = db_temp.rename(columns={
    'country_code': 'country_code',
    'year': 'year',
    'net_number_migrants': 'value'
})
db_temp['indicator'] = 'net_migration_onu'
db_temp['fuente'] = 'WPP2024 DEMOGRAPHIC INDICATORS'
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
df_plot=db_indicators[(db_indicators['indicator']=='net_migration_onu')]
title_plot="Net migration   -   ONU WPP2024"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='country_code', data=df_plot)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %%
# Filter the DataFrame
filtered_df = db_indicators[
    ((db_indicators['indicator'] == 'net_migration_onu') | (db_indicators['indicator'] == 'net_migration_calculated')) &
    (db_indicators['country_code'] == 'VEN') &
    (db_indicators['year'] >= 2010)
]

pivoted_df = filtered_df.pivot_table(index=['year', 'country_code'], columns='indicator', values='value').reset_index()

pivoted_df
# Out:
# indicator  year country_code net_migration_calculated net_migration_onu
# 0          2010          VEN                 784717.0          -52781.0
# 1          2011          VEN                 876863.0          -54384.0
# 2          2012          VEN                 898715.0          -55131.0
# 3          2013          VEN                 893608.0          -57818.0
# 4          2014          VEN                 857740.0          -62437.0
# 5          2015          VEN                 688181.0          -77417.0
# 6          2016          VEN                  39016.0         -283270.0
# 7          2017          VEN                -828574.0         -817376.0
# 8          2018          VEN               -1854911.0        -1355602.0
# 9          2019          VEN               -2964343.0         -975534.0
# 10         2020          VEN               -4089303.0         -524649.0
# 11         2021          VEN                      NaN         -332936.0
# 12         2022          VEN                      NaN         -141107.0
# 13         2023          VEN                      NaN         -112899.0

# %%
title_plot="Net migration  (inmigration- emigration) for Venezuela -   source comparition"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='indicator', data=filtered_df)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %%
# Filter the DataFrame
filtered_df = db_indicators[
    ((db_indicators['indicator'] == 'net_migration_onu') | (db_indicators['indicator'] == 'net_migration_calculated')) &
    (db_indicators['country_code'] == 'ARG') &
    (db_indicators['year'] >= 2010)
]


pivoted_df = filtered_df.pivot_table(index=['year', 'country_code'], columns='indicator', values='value').reset_index()

pivoted_df
# Out:
# indicator  year country_code net_migration_calculated net_migration_onu
# 0          2010          ARG                 844094.0           -5003.0
# 1          2011          ARG                 886857.0           -1117.0
# 2          2012          ARG                 944213.0            2978.0
# 3          2013          ARG                1001489.0            5275.0
# 4          2014          ARG                1056601.0            5794.0
# 5          2015          ARG                1096917.0            5464.0
# 6          2016          ARG                1133551.0            5215.0
# 7          2017          ARG                1155439.0            4931.0
# 8          2018          ARG                1162625.0            5742.0
# 9          2019          ARG                1168607.0            5397.0
# 10         2020          ARG                1168317.0             292.0
# 11         2021          ARG                      NaN             314.0
# 12         2022          ARG                      NaN            5589.0
# 13         2023          ARG                      NaN            4133.0

# %%
title_plot="Net migration  (inmigration- emigration) for Argentina -   source comparition"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='indicator', data=filtered_df)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %% [markdown]
# For the Venezuelan data, although very different, the CRIS-UNU calculation seems to make sense given the Venezuelan exodus, in fact it is lower than that reported by other channels.
#
# In the Argentine data the values are very rare. For UNO the net immigration value is very low, although it may be, given the lack of emigration data. The CRIS-UNU data, on the other hand, seem very high, since they are around the value of the stock of immigrants.
#
# ❗

# %%
print(df2.head())
# Out:
#   iso_or               origin iso_des destination  year  stock  flow  inflow  \
# 0    AAB  Antigua and Barbuda     ABW       Aruba  1960     16   NaN     NaN
# 1    AAB  Antigua and Barbuda     ABW       Aruba  1961     16   0.0     NaN
# 2    AAB  Antigua and Barbuda     ABW       Aruba  1962     15  -1.0     NaN
# 3    AAB  Antigua and Barbuda     ABW       Aruba  1963     15   0.0     NaN
# 4    AAB  Antigua and Barbuda     ABW       Aruba  1964     15   0.0     NaN
#
#    outflow
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df2_grouped = latam_mig_df.groupby(['year', 'iso_or'])['flow'].sum().reset_index()

# %%
df2_grouped = df2_grouped[df2_grouped['iso_or'].isin(countries)]
df2_grouped
# Out:
#      year iso_or       flow
# 0    1960    ARG        0.0
# 1    1960    BOL        0.0
# 2    1960    CHL        0.0
# 3    1960    VEN        0.0
# 4    1961    ARG     7159.0
# ..    ...    ...        ...
# 239  2019    VEN  1116603.0
# 240  2020    ARG    40724.0
# 241  2020    BOL    29341.0
# 242  2020    CHL    10715.0
# 243  2020    VEN  1135919.0
#
# [244 rows x 3 columns]

# %%
title_plot="Flow indicator /grouped by country) - CRIS-UNU"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='flow', hue='iso_or', data=df2_grouped)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('flow')
plt.show()

# %% [markdown]
# I'm not sure how this flow indicator is constructed..
# ❌

# %% [markdown]
# **I3.1	Total population**
#
# (total_pópulation_wb)
#
# World Bank API
# https://databank.worldbank.org/
#
#
# API information
# https://pypi.org/project/wbgapi/

# %%
import wbgapi as wb
pop_tot=wb.data.DataFrame('SP.POP.TOTL', ['ARG', 'CHL','BOL', 'VEN'], range(1960, 2022), labels=True)
pop_tot = pop_tot.reset_index()
pop_tot
# Out:
#   economy        Country      YR1960      YR1961      YR1962      YR1963  \
# 0     VEN  Venezuela, RB   8160090.0   8455915.0   8756870.0   9064021.0
# 1     BOL        Bolivia   3702323.0   3778731.0   3857493.0   3938913.0
# 2     CHL          Chile   8153350.0   8324802.0   8497059.0   8670144.0
# 3     ARG      Argentina  20386045.0  20726276.0  21072538.0  21421705.0
#
#        YR1964      YR1965      YR1966      YR1967  ...      YR2012  \
# 0   9377712.0   9697790.0  10024854.0  10358513.0  ...  29553826.0
# 1   4022996.0   4109796.0   4199550.0   4292572.0  ...  10515807.0
# 2   8842525.0   9012938.0   9181722.0   9348939.0  ...  17519119.0
# 3  21769453.0  22112629.0  22453893.0  22799059.0  ...  42161721.0
#
#        YR2013      YR2014      YR2015      YR2016      YR2017      YR2018  \
# 0  29912198.0  30254079.0  30573972.0  30765720.0  30565323.0  29807592.0
# 1  10682608.0  10848888.0  11014705.0  11180020.0  11344587.0  11508368.0
# 2  17687006.0  17864195.0  18047625.0  18267221.0  18558868.0  18893191.0
# 3  42582455.0  43024071.0  43477012.0  43900313.0  44288894.0  44654882.0
#
#        YR2019      YR2020      YR2021
# 0  28938098.0  28444077.0  28237826.0
# 1  11671386.0  11816299.0  11937360.0
# 2  19197744.0  19370624.0  19456334.0
# 3  44973465.0  45191965.0  45312281.0
#
# [4 rows x 64 columns]

# %%
# Realizar la transformación pivot usando melt

pop_latam = pop_tot.melt(id_vars=['economy', 'Country'],
                    value_vars=[col for col in pop_tot.columns if col.startswith('YR')],
                    var_name='year',
                    value_name='pop_total')

# Limpiar la columna 'YEAR' eliminando el prefijo 'YR'
pop_latam['year'] = pop_latam['year'].str.replace('YR', '')

# Mostrar las primeras filas de la tabla transformada
print(pop_latam.head())
# Out:
#   economy        Country  year   pop_total
# 0     VEN  Venezuela, RB  1960   8160090.0
# 1     BOL        Bolivia  1960   3702323.0
# 2     CHL          Chile  1960   8153350.0
# 3     ARG      Argentina  1960  20386045.0
# 4     VEN  Venezuela, RB  1961   8455915.0

# %%
#creo el indicador y lo agrego a la base
db_temp = pop_latam[['economy', 'year','pop_total']]
db_temp = db_temp.rename(columns={
    'economy': 'country_code',
    'year': 'year',
    'pop_total': 'value'
})
db_temp['indicator'] = 'total_population_wb'
db_temp['fuente'] = 'World Bank API'
print(db_temp.head())
# Out:
#   country_code  year       value            indicator          fuente
# 0          VEN  1960   8160090.0  total_population_wb  World Bank API
# 1          BOL  1960   3702323.0  total_population_wb  World Bank API
# 2          CHL  1960   8153350.0  total_population_wb  World Bank API
# 3          ARG  1960  20386045.0  total_population_wb  World Bank API
# 4          VEN  1961   8455915.0  total_population_wb  World Bank API

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
db_indicators['year'] = pd.to_numeric(db_indicators['year'], errors='coerce').astype('Int64')

# %%
filtered_df = db_indicators[db_indicators['indicator'] == 'total_population_wb']
country_df = filtered_df[filtered_df['country_code'].isin(countries)]

# Create the time series plot using seaborn
plt.figure(figsize=(12, 8))
sns.set_theme(style="darkgrid")
sns.lineplot(x='year', y='value', hue='country_code', data=country_df)

plt.xlabel('Year')
plt.ylabel('Total population')
plt.title('Total population Over Time ARG BOL CHL and VEN (total_population_wb)')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %% [markdown]
# I'll check the ONU population data..

# %%
df_onu.head()
# Out:
#   country_code  year  population  net_number_migrants  rate_net_migration
# 0          ARG  1950    16849682                60480                 3.6
# 1          ARG  1951    17186391                54478                 3.1
# 2          ARG  1952    17526543                48149                 2.7
# 3          ARG  1953    17871212                41687                 2.3
# 4          ARG  1954    18211391                35623                 1.9

# %%
db_temp = df_onu[['country_code', 'year','population']]
db_temp = db_temp.rename(columns={
    'country_code': 'country_code',
    'year': 'year',
    'population': 'value'
})
db_temp['indicator'] = 'population_onu'
db_temp['fuente'] = 'WPP2024 DEMOGRAPHIC INDICATORS'
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
df_plot=db_indicators[(db_indicators['indicator']=='population_onu')]
title_plot="Population   -   ONU WPP2024"
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='value', hue='country_code', data=df_plot)
plt.title(f'{title_plot}')
plt.xlabel('Year')
plt.ylabel('Qty')
plt.show()

# %% [markdown]
# **I3.2	International migrant stock (% of population)**
#
# migration_pct_wb

# %%
mig_pct=wb.data.DataFrame('SM.POP.TOTL.ZS', ['ARG', 'CHL','BOL','VEN'], range(1960, 2022), labels=True)
mig_pct = mig_pct.reset_index()
mig_pct
# Out:
#   economy        Country  YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  \
# 0     VEN  Venezuela, RB     NaN     NaN     NaN     NaN     NaN     NaN
# 1     BOL        Bolivia     NaN     NaN     NaN     NaN     NaN     NaN
# 2     CHL          Chile     NaN     NaN     NaN     NaN     NaN     NaN
# 3     ARG      Argentina     NaN     NaN     NaN     NaN     NaN     NaN
#
#    YR1966  YR1967  ...  YR2012  YR2013  YR2014    YR2015  YR2016  YR2017  \
# 0     NaN     NaN  ...     NaN     NaN     NaN  4.514737     NaN     NaN
# 1     NaN     NaN  ...     NaN     NaN     NaN  1.333267     NaN     NaN
# 2     NaN     NaN  ...     NaN     NaN     NaN  2.615513     NaN     NaN
# 3     NaN     NaN  ...     NaN     NaN     NaN  4.805292     NaN     NaN
#
#    YR2018  YR2019  YR2020  YR2021
# 0     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN
#
# [4 rows x 64 columns]

# %%
# Realizar la transformación pivot usando melt

mig_pct = mig_pct.melt(id_vars=['economy', 'Country'],
                    value_vars=[col for col in mig_pct.columns if col.startswith('YR')],
                    var_name='year',
                    value_name='mig_pct')

# Limpiar la columna 'YEAR' eliminando el prefijo 'YR'
mig_pct['year'] = mig_pct['year'].str.replace('YR', '')

# Drop rows where 'mig_pct' is NaN
mig_pct = mig_pct.dropna(subset=['mig_pct'])

# Mostrar las primeras filas de la tabla transformada
print(mig_pct.head())
# Out:
#     economy        Country  year   mig_pct
# 120     VEN  Venezuela, RB  1990  5.160664
# 121     BOL        Bolivia  1990  1.075778
# 122     CHL          Chile  1990  0.818045
# 123     ARG      Argentina  1990  5.041039
# 140     VEN  Venezuela, RB  1995  4.596922

# %%
#creo el indicador y lo agrego a la base
db_temp = mig_pct[['economy', 'year','mig_pct']]
db_temp = db_temp.rename(columns={
    'economy': 'country_code',
    'year': 'year',
    'mig_pct': 'value'
})
db_temp['indicator'] = 'migration_pct_wb'
db_temp['fuente'] = 'World Bank API'
print(db_temp.head())
# Out:
#     country_code  year     value         indicator          fuente
# 120          VEN  1990  5.160664  migration_pct_wb  World Bank API
# 121          BOL  1990  1.075778  migration_pct_wb  World Bank API
# 122          CHL  1990  0.818045  migration_pct_wb  World Bank API
# 123          ARG  1990  5.041039  migration_pct_wb  World Bank API
# 140          VEN  1995  4.596922  migration_pct_wb  World Bank API

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
# prompt: filter db_indicators by indicator==migration_pct_wb  and create a barplot with seaborn for ARG and CHL by year

# Filter db_indicators for indicator == 'migration_pct_wb'
migration_pct_df = db_indicators[db_indicators['indicator'] == 'migration_pct_wb']

# Create the bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="darkgrid")
ax = sns.barplot(x='year', y='value', hue='country_code', data=migration_pct_df)


# Annotate bars with percentage values
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=8, color='black', xytext=(0, 5),
            textcoords='offset points')


plt.xlabel('Year')
plt.ylabel('Migration Percentage ')
plt.title('Migration Percentage (World Bank)')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %% [markdown]
# **Calculate the %of migration by inmigration_stock (UNU-CRIS) and total population (World Banck)**

# %%
# Filter for the specified indicators
indicators_to_keep = ['inmigration_stock', 'total_population_wb']
df_filtered = db_indicators[db_indicators['indicator'].isin(indicators_to_keep)]

# Display the filtered DataFrame
print(df_filtered.head())
# Out:
#   country_code  year      value          indicator    fuente
# 0          ARG  1960  2683416.0  inmigration_stock  UNU-CRIS
# 1          BOL  1960    43730.0  inmigration_stock  UNU-CRIS
# 2          CHL  1960   109563.0  inmigration_stock  UNU-CRIS
# 3          VEN  1960   510822.0  inmigration_stock  UNU-CRIS
# 4          ARG  1961  2630230.0  inmigration_stock  UNU-CRIS

# %%
df_filtered['year'] = df_filtered['year'].astype(int)
# Out:
# <ipython-input-92-fb0a7a6588e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['year'] = df_filtered['year'].astype(int)

# %%
pivot_df = df_filtered.pivot_table(index=['year','country_code'], columns='indicator', values='value').reset_index()
pivot_df
# Out:
# indicator  year country_code inmigration_stock total_population_wb
# 0          1960          ARG         2683416.0          20386045.0
# 1          1960          BOL           43730.0           3702323.0
# 2          1960          CHL          109563.0           8153350.0
# 3          1960          VEN          510822.0           8160090.0
# 4          1961          ARG         2630230.0          20726276.0
# ..          ...          ...               ...                 ...
# 243        2020          VEN         1325156.0          28444077.0
# 244        2021          ARG               NaN          45312281.0
# 245        2021          BOL               NaN          11937360.0
# 246        2021          CHL               NaN          19456334.0
# 247        2021          VEN               NaN          28237826.0
#
# [248 rows x 4 columns]

# %%
# Calculate the proportion
pivot_df['pct_of_pop'] = pivot_df['inmigration_stock']/pivot_df['total_population_wb']*100
pivot_df
# Out:
# indicator  year country_code inmigration_stock total_population_wb pct_of_pop
# 0          1960          ARG         2683416.0          20386045.0  13.163004
# 1          1960          BOL           43730.0           3702323.0    1.18115
# 2          1960          CHL          109563.0           8153350.0   1.343779
# 3          1960          VEN          510822.0           8160090.0   6.260004
# 4          1961          ARG         2630230.0          20726276.0  12.690316
# ..          ...          ...               ...                 ...        ...
# 243        2020          VEN         1325156.0          28444077.0   4.658812
# 244        2021          ARG               NaN          45312281.0        NaN
# 245        2021          BOL               NaN          11937360.0        NaN
# 246        2021          CHL               NaN          19456334.0        NaN
# 247        2021          VEN               NaN          28237826.0        NaN
#
# [248 rows x 5 columns]

# %%
# Create the time series plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="darkgrid")
sns.lineplot(x='year', y='pct_of_pop', hue='country_code', data=pivot_df)

plt.xlabel('Year')
plt.ylabel('Percentage of Population')
plt.title('Percentage of Population (Immigration Stock / Total Population) Over Time ')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %%
#creo el indicador y lo agrego a la base
db_temp =  pivot_df[['year', 'country_code', 'pct_of_pop']]
db_temp = db_temp.rename(columns={
    'country_cod': 'country_code',
    'year': 'year',
    'pct_of_pop': 'value'
})
db_temp['indicator'] = 'migration_pct_calc'
db_temp['fuente'] = 'Calculated by I3-1 & I2.1'
print(db_temp.head())
# Out:
# indicator  year country_code      value           indicator  \
# 0          1960          ARG  13.163004  migration_pct_calc
# 1          1960          BOL    1.18115  migration_pct_calc
# 2          1960          CHL   1.343779  migration_pct_calc
# 3          1960          VEN   6.260004  migration_pct_calc
# 4          1961          ARG  12.690316  migration_pct_calc
#
# indicator                     fuente
# 0          Calculated by I3-1 & I2.1
# 1          Calculated by I3-1 & I2.1
# 2          Calculated by I3-1 & I2.1
# 3          Calculated by I3-1 & I2.1
# 4          Calculated by I3-1 & I2.1

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %% [markdown]
# **I3.3 GDP (US$)**
#
# (gdp_wb)

# %%
gdp=wb.data.DataFrame('NY.GDP.MKTP.CD', ['ARG', 'CHL','BOL', 'VEN'], range(1960, 2022), labels=True)
gdp = gdp.reset_index()
gdp
# Out:
#   economy        Country        YR1960        YR1961        YR1962  \
# 0     VEN  Venezuela, RB  7.663938e+09  8.067267e+09  8.814310e+09
# 1     BOL        Bolivia  3.732500e+08  4.060000e+08  4.439167e+08
# 2     CHL          Chile  4.110000e+09  4.829238e+09  5.631285e+09
# 3     ARG      Argentina           NaN           NaN  2.445060e+10
#
#          YR1963        YR1964        YR1965        YR1966        YR1967  ...  \
# 0  9.608717e+09  8.192414e+09  8.427778e+09  8.781333e+09  9.250000e+09  ...
# 1  4.780000e+08  5.385833e+08  5.983333e+08  6.625000e+08  7.482500e+08  ...
# 2  5.591307e+09  5.964196e+09  6.108679e+09  7.162633e+09  7.057478e+09  ...
# 3  1.827212e+10  2.560525e+10  2.834471e+10  2.863047e+10  2.425667e+10  ...
#
#          YR2012        YR2013        YR2014        YR2015        YR2016  \
# 0  3.812862e+11  3.710054e+11  4.823593e+11           NaN           NaN
# 1  2.708450e+10  3.065934e+10  3.299619e+10  3.300020e+10  3.394113e+10
# 2  2.670248e+11  2.773950e+11  2.595610e+11  2.424504e+11  2.493449e+11
# 3  5.459824e+11  5.520251e+11  5.263197e+11  5.947493e+11  5.575323e+11
#
#          YR2017        YR2018        YR2019        YR2020        YR2021
# 0           NaN           NaN           NaN           NaN           NaN
# 1  3.750864e+10  4.028765e+10  4.089532e+10  3.662984e+10  4.040611e+10
# 2  2.761543e+11  2.958576e+11  2.782851e+11  2.540422e+11  3.155150e+11
# 3  6.436284e+11  5.248199e+11  4.477547e+11  3.857405e+11  4.865641e+11
#
# [4 rows x 64 columns]

# %%
# Realizar la transformación pivot usando melt
gdp = gdp.melt(id_vars=['economy', 'Country'],
                    value_vars=[col for col in gdp.columns if col.startswith('YR')],
                    var_name='year',
                    value_name='gdp')

# Limpiar la columna 'YEAR' eliminando el prefijo 'YR'
gdp['year'] = gdp['year'].str.replace('YR', '')

# Mostrar las primeras filas de la tabla transformada
print(gdp.head())
# Out:
#   economy        Country  year           gdp
# 0     VEN  Venezuela, RB  1960  7.663938e+09
# 1     BOL        Bolivia  1960  3.732500e+08
# 2     CHL          Chile  1960  4.110000e+09
# 3     ARG      Argentina  1960           NaN
# 4     VEN  Venezuela, RB  1961  8.067267e+09

# %%
#creo el indicador y lo agrego a la base
db_temp = gdp[['economy', 'year','gdp']]
db_temp = db_temp.rename(columns={
    'economy': 'country_code',
    'year': 'year',
    'gdp': 'value'
})
db_temp['indicator'] = 'gdp_wb'
db_temp['fuente'] = 'World Bank API'
print(db_temp.head())
# Out:
#   country_code  year         value indicator          fuente
# 0          VEN  1960  7.663938e+09    gdp_wb  World Bank API
# 1          BOL  1960  3.732500e+08    gdp_wb  World Bank API
# 2          CHL  1960  4.110000e+09    gdp_wb  World Bank API
# 3          ARG  1960           NaN    gdp_wb  World Bank API
# 4          VEN  1961  8.067267e+09    gdp_wb  World Bank API

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
# Convert 'year' column to integer
db_indicators['year'] = db_indicators['year'].astype(int)

# %%
# Filter for indicator = 'db_temp['indicator'] = 'emigration_stock'

filtered_df = db_indicators[db_indicators['indicator'] == 'gdp_wb']

# Create the time series plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="darkgrid")
sns.lineplot(x='year', y='value', hue='country_code', data=filtered_df)

plt.xlabel('Year')
plt.ylabel('GDP ')
plt.title('GDP (current US$) Over Time  (gdp_wb)')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %% [markdown]
# **I3.3 Gini index	**
# (SI.POV.GINI)
#
# (gini_wb)

# %%
gini=wb.data.DataFrame('SI.POV.GINI', ['ARG', 'CHL','BOL', 'VEN'], range(1960, 2022), labels=True)
gini = gini.reset_index()
gini
# Out:
#   economy        Country  YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  \
# 0     VEN  Venezuela, RB     NaN     NaN     NaN     NaN     NaN     NaN
# 1     BOL        Bolivia     NaN     NaN     NaN     NaN     NaN     NaN
# 2     CHL          Chile     NaN     NaN     NaN     NaN     NaN     NaN
# 3     ARG      Argentina     NaN     NaN     NaN     NaN     NaN     NaN
#
#    YR1966  YR1967  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# 0     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN  ...    46.6    47.6    47.8    46.7    45.2    44.6
# 2     NaN     NaN  ...     NaN    46.8     NaN    45.3     NaN    45.3
# 3     NaN     NaN  ...    41.4    41.1    41.8     NaN    42.3    41.4
#
#    YR2018  YR2019  YR2020  YR2021
# 0     NaN     NaN     NaN     NaN
# 1    42.6    41.6    43.6    40.9
# 2     NaN     NaN    47.0     NaN
# 3    41.7    43.3    42.7    42.4
#
# [4 rows x 64 columns]

# %%
# Realizar la transformación pivot usando melt

gini = gini.melt(id_vars=['economy', 'Country'],
                    value_vars=[col for col in gini.columns if col.startswith('YR')],
                    var_name='year',
                    value_name='gini')

# Limpiar la columna 'YEAR' eliminando el prefijo 'YR'
gini['year'] = gini['year'].str.replace('YR', '')

# Mostrar las primeras filas de la tabla transformada
print(gini.head())
# Out:
#   economy        Country  year  gini
# 0     VEN  Venezuela, RB  1960   NaN
# 1     BOL        Bolivia  1960   NaN
# 2     CHL          Chile  1960   NaN
# 3     ARG      Argentina  1960   NaN
# 4     VEN  Venezuela, RB  1961   NaN

# %%
#creo el indicador y lo agrego a la base
db_temp = gini[['economy', 'year','gini']]
db_temp = db_temp.rename(columns={
    'economy': 'country_code',
    'year': 'year',
    'gini': 'value'
})
db_temp['indicator'] = 'gini_wb'
db_temp['fuente'] = 'World Bank API'

db_temp = db_temp.dropna(subset=['value'])
print(db_temp.head())
# Out:
#     country_code  year  value indicator          fuente
# 83           ARG  1980   40.8   gini_wb  World Bank API
# 84           VEN  1981   55.6   gini_wb  World Bank API
# 107          ARG  1986   42.8   gini_wb  World Bank API
# 108          VEN  1987   53.4   gini_wb  World Bank API
# 110          CHL  1987   56.2   gini_wb  World Bank API

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
# Convert 'year' column to integer
db_indicators['year'] = db_indicators['year'].astype(int)

# %%
filtered_df = db_indicators[db_indicators['indicator'] == 'gini_wb']

# Create the time series plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="darkgrid")
sns.lineplot(x='year', y='value', hue='country_code', data=filtered_df)

plt.xlabel('Year')
plt.ylabel('GINI ')
plt.title('GINI index Over Time for CHL and ARG (gini_wb)')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %% [markdown]
# **I3.4 Poverty headcount ratio at national poverty lines (% of population) (SI.POV.NAHC)**
#
# poverty_wb

# %%
pov=wb.data.DataFrame('SI.POV.NAHC', ['ARG', 'CHL','BOL', 'VEN'], range(1990, 2022), labels=True)
pov = pov.reset_index()
pov
# Out:
#   economy        Country  YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  \
# 0     VEN  Venezuela, RB     NaN     NaN     NaN     NaN     NaN     NaN
# 1     BOL        Bolivia     NaN     NaN     NaN     NaN     NaN     NaN
# 2     CHL          Chile     NaN     NaN     NaN     NaN     NaN     NaN
# 3     ARG      Argentina     NaN     NaN     NaN     NaN     NaN     NaN
#
#    YR1996  YR1997  ...  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# 0     NaN     NaN  ...    27.2    29.4    29.5    33.1     NaN     NaN
# 1     NaN     NaN  ...    43.3    38.9    39.1    38.6    39.5    36.4
# 2     NaN     NaN  ...     NaN    14.4     NaN    11.7     NaN     8.6
# 3     NaN     NaN  ...     NaN     NaN     NaN     NaN    30.3    25.7
#
#    YR2018  YR2019  YR2020  YR2021
# 0     NaN     NaN     NaN     NaN
# 1    34.5    37.2    39.0    36.4
# 2     NaN     NaN    10.8     NaN
# 3    32.0    35.5    42.0    37.3
#
# [4 rows x 34 columns]

# %%
# Realizar la transformación pivot usando melt

pov = pov.melt(id_vars=['economy', 'Country'],
                    value_vars=[col for col in pov.columns if col.startswith('YR')],
                    var_name='year',
                    value_name='pov')

# Limpiar la columna 'YEAR' eliminando el prefijo 'YR'
pov['year'] = pov['year'].str.replace('YR', '')

# Mostrar las primeras filas de la tabla transformada
print(pov.head())
# Out:
#   economy        Country  year  pov
# 0     VEN  Venezuela, RB  1990  NaN
# 1     BOL        Bolivia  1990  NaN
# 2     CHL          Chile  1990  NaN
# 3     ARG      Argentina  1990  NaN
# 4     VEN  Venezuela, RB  1991  NaN

# %%
#creo el indicador y lo agrego a la base
db_temp = pov[['economy', 'year','pov']]
db_temp = db_temp.rename(columns={
    'economy': 'country_code',
    'year': 'year',
    'pov': 'value'
})
db_temp['indicator'] = 'poverty_wb'
db_temp['fuente'] = 'World Bank API'

db_temp = db_temp.dropna(subset=['value'])
print(db_temp.head())
# Out:
#    country_code  year  value   indicator          fuente
# 40          VEN  2000   41.6  poverty_wb  World Bank API
# 41          BOL  2000   66.4  poverty_wb  World Bank API
# 42          CHL  2000   36.0  poverty_wb  World Bank API
# 44          VEN  2001   31.1  poverty_wb  World Bank API
# 45          BOL  2001   63.1  poverty_wb  World Bank API

# %%
db_indicators = pd.concat([db_indicators, db_temp], axis=0)

# %%
# Convert 'year' column to integer
db_indicators['year'] = db_indicators['year'].astype(int)

# %%
filtered_df = db_indicators[db_indicators['indicator'] == 'poverty_wb']

# Create the time series plot using seaborn
plt.figure(figsize=(10, 6))
sns.set_theme(style="darkgrid")
sns.lineplot(x='year', y='value', hue='country_code', data=filtered_df)

plt.xlabel('Year')
plt.ylabel('Poverty ')
plt.title('Poverty headcount ratio at national poverty lines (% of population)  (poverty_wb)')
plt.legend(title='Country Code')
plt.grid(True)
plt.show()

# %% [markdown]
# Los datos de pobreza están incompletos. Hay que buscar la información local para los últimos años y reconstruirlo para Arg y Venezuela

# %%
db_indicators.to_csv('db_indicators.csv', index=False)
